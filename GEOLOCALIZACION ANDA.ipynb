# %%
#basic library

# %%
import csv
import os
import time

# %%
import numpy as np

# %%
 from geopy.point import Point

# %%
#basic base addres csv

# %%
os.chdir('C:/Users/diego/OneDrive/Escritorio/Campaña//')

# %%
#basic library to transform addresses into coordinates

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="sample app")

# %%
#FUNCIONA NO TOCAR

# %%
#GEOLOCALIZACION DIRECTA(DOM A COORDENADAS CARTESIANAS)

# %%
total_capturados=0
total_no_capturados=0
with open('Padrón de ausentes con direccion.xlsx - Hoja1.csv', encoding="utf8") as csv_file:
    csv_data = csv.reader(csv_file, delimiter=',', quotechar='\'')
    with open('Padrón_Ausentes_Cordenadas.csv','w') as csv_aus:
        name_csv=['Apellidos','Nombres','Año','Edad','Dni','Lat','Long']
        writer= csv.DictWriter(csv_aus,fieldnames=name_csv, delimiter=',')   
        writer.writeheader()
        with open('Padrón_Ausentes_Cordenadas_No_Calculables.csv','w') as csv_aus2:
            name_csv2=['Apellidos','Nombres','Año','Edad','Dni','Domicilio']
            writer2= csv.DictWriter(csv_aus2,fieldnames=name_csv2, delimiter=',')   
            writer2.writeheader()
            for row in csv_data:  
                    print('hola')
                    geodir = geolocator.geocode('{},Pila,Buenos Aires,Argentina'.format(row[7]), timeout=None)
                    if(geodir!=None):
                        lat=geodir.raw.get('lat')
                        lon=geodir.raw.get('lon')
                        #if(lat!=None):
                         #if(lon!=None):
                        print(row[2], row[3], row[7])
                        apellido=row[2]
                        nombre=row[3]
                        fec=row[4]
                        edad=row[5]
                        dni=row[6]
                        persona={'Apellidos':apellido, 'Nombres':nombre, 'Año':fec, 'Edad':edad,'Dni':dni,'Lat':lat,'Long':lon}
                        #print(persona)  
                        writer.writerow(persona)
                        total_capturados+=1
                    else:
                        apellido=row[2]
                        nombre=row[3]
                        fec=row[4]
                        edad=row[5]
                        dni=row[6]
                        dom=row[7]
                        persona2={'Apellidos':apellido, 'Nombres':nombre, 'Año':fec, 'Edad':edad,'Dni':dni,'Domicilio':dom}
                        #(persona2)  
                        writer2.writerow(persona2)
                        total_no_capturados+=1
# Out:
# hola
# hola
# ACEVEDO SANCHEZ ANTONIO EDUARDO PLANES DE CASCO MAXIMA 150
# hola
# hola
# ACOSTA CARLOS ALBERTO MARIANO MORENO 244
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# ALARCON SEBASTIAN 4 931
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# ALEGRE ROCIO ROSANA PJE.CASALINS 0
# hola
# hola
# hola
# ALFONSIN MARIA MILAGROS PLANES DE CASCO MAXIMA 270
# hola
# hola
# hola
# hola
# hola
# hola
# ALVAREZ NIVIA NOEMI 2 522
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# ALVAREZ MARIA ANTONIA 6 E/17 Y 19
# hola
# hola
# hola
# ALVAREZ MARINA ESTEFANIA BARTOLOME MITRE 388
# hola
# hola
# hola
# hola
# hola
# AMADO NORBERTO RAMON FACUNDO QUIROGA 1071
# hola
# hola
# hola
# hola
# hola
# AMAYA NILDA ADELAIDA 15 120
# hola
# hola
# hola
# ANDINA PEDRO FORTUNATO MITRE 410
# hola
# ANDINA VERONICA FERNANDA MITRE 410
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# ARBIO ROBERTO OMAR 5 36
# hola
# hola
# ARBIO MAYRA JOHANA BELGRANO 1244
# hola
# hola
# hola
# hola
# ARIAS NILDA SOFIA 4 E 13 Y 15
# hola
# ARIAS NESTOR FABIAN 8 E/23 Y 25 N° 1130
# hola
# ARIZMENDI MICAELA MILAGROS ALEM LEANDRO N. 471
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# AVALOS JUAN PABLO ANGEL "RUTA 57 KM 8
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# AZURI ANA ISABEL MARIANO MORENO 560
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# CASTELLS JOSÉ LUIS MORENO MARIANO 1010
# hola
# CASTELLS NILDA ELAINE MORENO MARIANO 1026
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# CEVASCO SEBASTIAN 2
# hola
# CHESINI EMMANUEL GASTON 11 N° 69
# hola
# hola
# CISNERO MIRTHA NILDA SARMIENTO 256
# hola
# hola
# COLUNGA MIRYAM EMILSE 6 E 13 Y 15
# hola
# COMASCHI NAZARENA ABRIL 23 449
# hola
# COÑAQUEO PABLO OSVALDO BROWN 3423
# hola
# CONTRERA ELIDA ISABEL 6 693
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# CORNEJO AGUSTIN 8 279
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# COSTANZO CARMEN BEATRIZ "6 174
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# DE FELIPE NELIDA NOEMI 6 E/23 Y 25
# hola
# hola
# hola
# hola
# DE FREITAS MICHELLE NAHIR GUEMES 63
# hola
# hola
# DE LA CANAL RUFINA MAGDALENA MARIANO MORENO 630
# hola
# hola
# DE LEON JULIO BENJAMIN 19 85
# hola
# DE LEON JUANA EUGENIA 6 631
# hola
# DE LEON CRISTIAN OSCAR 6 890
# hola
# hola
# hola
# hola
# DE LEON GARATE JUAN GERMAN IGNACIO 13 12
# hola
# hola
# hola
# hola
# hola
# DEL CAMPO PEDRO HUMBERTO FACUNDO QUIROGA 1147
# hola
# hola
# hola
# hola
# hola
# DELICIO ROBERTO BELTRAN 6 818
# hola
# hola
# DELLI QUADRI MARIANO ALBERTO MORENO 876
# hola
# DEMETRIO JONATAN MANUEL BELGRANO 595
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# DOMECQ BARBARA DAIANA ALBERDI 245
# hola
# hola
# hola
# hola
# DUFAU JUAN JOSE 23 177
# hola
# DUFUR OSCAR ALBERTO 4 1551
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# ECHEVERRIA RODRIGO EZEQUIEL 21 434
# hola
# hola
# hola
# hola
# ENCARNACION CLELIA MORENO MARIANO 1340
# hola
# hola
# hola
# hola
# hola
# ERISTA JULIO ARGENTINO 6 E/11 Y 13
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# ESTABIL DOMINGA ELINA DOMINGO RIGOL 52
# hola
# hola
# hola
# hola
# hola
# ETCHART LAZARO DANILO 8 237
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# FERREYRA SONIA SUSANA 4 1168
# hola
# hola
# FILIPPA SEBASTIAN GABRIEL BELGRANO 553
# hola
# FILIPPA ALEJANDRO DANIEL BELGRANO 553
# hola
# hola
# FINOCHIETTO ADELA RAQUEL 2 392
# hola
# hola
# FINOCHIETTO CELICA SUSANA CALLE 8 655
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# FRAILUNA SOFIA 10 1138
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# GALLO EZEQUIEL MARIANO MORENO 620
# hola
# GALLO JUAN CARLOS MARIANO MORENO 620
# hola
# GAMBOA MARIA BELEN 4 E/17 Y 19
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# GILES ELSA SUSANA 11 46
# hola
# hola
# hola
# hola
# hola
# GODOY EULALIA BEATRIZ URQUIZA JUSTO JOSE DE 9
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# GONZALEZ MATIAS ALEJANDRO 11 Y 13 551
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# HERMIDA OLGA ISABEL 21 177
# hola
# hola
# hola
# hola
# HERNANDEZ REINALDO I ARTURO ILLIA 138
# hola
# hola
# hola
# HERRERA JORGELINA ELIZABETH 12 612
# hola
# hola
# HIRSCHFELD EZEQUIEL BENITO MARIANO MORENO 1034
# hola
# hola
# hola
# hola
# hola
# hola
# IBARGUREN VIVIANA ESTHER 13 235
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# JAIME DARIO ADALBERTO 0
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# LANCIERI CLAUDIO RAUL 6 E/ 13 Y 15
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# LAZARTE CRISTIAN LUIS 11 547
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# LEONE JUAN FRANCISCO 19 243
# hola
# LEONE JUAN JOSE 19 243
# hola
# hola
# hola
# hola
# hola
# hola
# LETOURNEAU MARÍA FERNANDA "4 1322
# hola
# LEZCANO HECTOR MIGUEL 12 860
# hola
# LEZCANO SERGIO GUSTAVO CHAPALAUQUEN S/N
# hola
# hola
# hola
# hola
# LEZCANO HECTOR ANIBAL MANUEL BELGRANO 1205
# hola
# LIBERTO ADRIANA LUCIA ALBERDI 245
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# LOPEZ MERCEDES CHAPALAUQUEN 0
# hola
# hola
# hola
# hola
# hola
# LOPEZ ESTEBAN EZEQUIEL JOSE DE URQUIZA 39
# hola
# LOPEZ CARMEN ESTHER MANUEL BELGRANO 341
# hola
# hola
# hola
# LOPEZ GONZALEZ KAREN MALENA RUTA 41 KM 49
# hola
# hola
# hola
# hola
# hola
# LUGONES DANIEL MARIANO 13 282
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# MAIDANA DIEGO DEMIAN 13 435
# hola
# hola
# hola
# MALDONADO ELSA LIBERTAD 6 E/23 Y 25 1162
# hola
# hola
# hola
# MARFORIO ALAN EZEQUIEL 10 1171
# hola
# hola
# MARINELLI LARA GIOVANNA ALMIRANTE BROWN 946
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# MARTINEZ MACEIRA MARIA AGUSTINA BARTOLOME MITRE 452
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# MEDINA BERTA ELSA 6 335
# hola
# hola
# MEDINA RODOLFO HORACIO 8 304
# hola
# hola
# hola
# hola
# hola
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x00000261F2D580D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     753             )
# --> 754             return self.urlopen(
#     755                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     753             )
# --> 754             return self.urlopen(
#     755                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=15+E%2F+10+Y+12+460%2CPila%2CBuenos+Aires%2CArgentina&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000261F2D580D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\geopy\adapters.py in _request(self, url, timeout, headers)
#     447         try:
# --> 448             resp = self.session.get(url, timeout=timeout, headers=headers)
#     449         except Exception as error:
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     542         kwargs.setdefault('allow_redirects', True)
# --> 543         return self.request('GET', url, **kwargs)
#     544
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=15+E%2F+10+Y+12+460%2CPila%2CBuenos+Aires%2CArgentina&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000261F2D580D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# <ipython-input-11-1d369f40c54f> in <module>
#      13             for row in csv_data:
#      14                     print('hola')
# ---> 15                     geodir = geolocator.geocode('{},Pila,Buenos Aires,Argentina'.format(row[7]), timeout=None)
#      16                     time.sleep(3)
#      17                     if(geodir!=None):
#
# ~\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296         callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297         return self._call_geocoder(url, callback, timeout=timeout)
#     298
#     299     def reverse(
#
# ~\anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, callback, timeout, is_json, headers)
#     366         try:
#     367             if is_json:
# --> 368                 result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369             else:
#     370                 result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# ~\anaconda3\lib\site-packages\geopy\adapters.py in get_json(self, url, timeout, headers)
#     436
#     437     def get_json(self, url, *, timeout, headers):
# --> 438         resp = self._request(url, timeout=timeout, headers=headers)
#     439         try:
#     440             return resp.json()
#
# ~\anaconda3\lib\site-packages\geopy\adapters.py in _request(self, url, timeout, headers)
#     458                     raise GeocoderServiceError(message)
#     459                 else:
# --> 460                     raise GeocoderUnavailable(message)
#     461             elif isinstance(error, requests.Timeout):
#     462                 raise GeocoderTimedOut("Service timed out")
#
# GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=15+E%2F+10+Y+12+460%2CPila%2CBuenos+Aires%2CArgentina&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000261F2D580D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
print('la cantidad de domicilios fueron convertidos son: {} '.format(total_capturados))
print('la cantidad de domicilios que no fueron convertidos son: {} '.format(total_no_capturados))

# %%
p1=total_capturados/(total_capturados+total_no_capturados)
p2=1-p1
print('El porcentaje exito de conversion fue el {}% de la muestra '.format(p1))
print('El porcentaje fallido de conversion fue: {}% de la muestra '.format(p2))
